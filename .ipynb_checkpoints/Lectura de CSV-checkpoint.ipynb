# %%
import pandas as pd

# %%
dataframe_general= pd.read_csv('visita19.csv',index_col=0)

# %%
dataframe_general
# Out:
#                 ENT_REGIS,C,2  MES_ENTREV,N,2,0  DIA_ENTREV,N,1,0  SEXO,N,1,0  \
# ANIO_ESTAD,C,4
# 2019                        1                 7                 1           2
# 2019                        1                 7                 1           2
# 2019                        1                 7                 1           2
# 2019                        1                 7                 1           1
# 2019                        1                 7                 1           1
# ...                       ...               ...               ...         ...
# 2019                       32                10                 1           1
# 2019                       32                10                 1           2
# 2019                       32                10                 1           1
# 2019                       32                10                 1           2
# 2019                       32                10                 1           2
#
# ...
